# %%
import pandas as pd
import numpy as np
import numpy.char as char

# %%
cp=pd.read_csv('/Users/macbookpro/Downloads/car_price.csv')

# %%
cp.head(20)
# Out:
#     symboling normalized_losses Fuel_type   make num_of_doors   aspiration  \
# 0           3                 ?       gas    std          two  convertible
# 1           3                 ?       gas    std          two  convertible
# 2           1                 ?       gas    std          two    hatchback
# 3           2               164       gas    std         four        sedan
# 4           2               164       gas    std         four        sedan
# 5           2                 ?       gas    std          two        sedan
# 6           1               158       gas    std         four        sedan
# 7           1                 ?       gas    std         four        wagon
# 8           1               158       gas  turbo         four        sedan
# 9           0                 ?       gas  turbo          two    hatchback
# 10          2               192       gas    std          two        sedan
# 11          0               192       gas    std         four        sedan
# 12          0               188       gas    std          two        sedan
# 13          0               188       gas    std         four        sedan
# 14          1                 ?       gas    std         four        sedan
# 15          0                 ?       gas    std         four        sedan
# 16          0                 ?       gas    std          two        sedan
# 17          0                 ?       gas    std         four        sedan
# 18          2               121       gas    std          two    hatchback
# 19          1                98       gas    std          two    hatchback
#
#    wheel_base engine_location  drive_wheels   body_style  ...  engine_size  \
# 0         rwd           front          88.6  alfa-romero  ...          130
# 1         rwd           front          88.6  alfa-romero  ...          130
# 2         rwd           front          94.5  alfa-romero  ...          152
# 3         fwd           front          99.8         audi  ...          109
# 4         4wd           front          99.4         audi  ...          136
# 5         fwd           front          99.8         audi  ...          136
# 6         fwd           front         105.8         audi  ...          136
# 7         fwd           front         105.8         audi  ...          136
# 8         fwd           front         105.8         audi  ...          131
# 9         4wd           front          99.5         audi  ...          131
# 10        rwd           front         101.2          bmw  ...          108
# 11        rwd           front         101.2          bmw  ...          108
# 12        rwd           front         101.2          bmw  ...          164
# 13        rwd           front         101.2          bmw  ...          164
# 14        rwd           front         103.5          bmw  ...          164
# 15        rwd           front         103.5          bmw  ...          209
# 16        rwd           front         103.5          bmw  ...          209
# 17        rwd           front         110.0          bmw  ...          209
# 18        fwd           front          88.4    chevrolet  ...           61
# 19        fwd           front          94.5    chevrolet  ...           90
#
#     fuel_system  bore  stroke compression_ratio horsepower  peak_rpm city_mpg  \
# 0          mpfi  3.47    2.68               9.0        111      5000       21
# 1          mpfi  3.47    2.68               9.0        111      5000       21
# 2          mpfi  2.68    3.47               9.0        154      5000       19
# 3          mpfi  3.19     3.4              10.0        102      5500       24
# 4          mpfi  3.19     3.4               8.0        115      5500       18
# 5          mpfi  3.19     3.4               8.5        110      5500       19
# 6          mpfi  3.19     3.4               8.5        110      5500       19
# 7          mpfi  3.19     3.4               8.5        110      5500       19
# 8          mpfi  3.13     3.4               8.3        140      5500       17
# 9          mpfi  3.13     3.4               7.0        160      5500       16
# 10         mpfi   3.5     2.8               8.8        101      5800       23
# 11         mpfi   3.5     2.8               8.8        101      5800       23
# 12         mpfi  3.31    3.19               9.0        121      4250       21
# 13         mpfi  3.31    3.19               9.0        121      4250       21
# 14         mpfi  3.31    3.19               9.0        121      4250       20
# 15         mpfi  3.62    3.39               8.0        182      5400       16
# 16         mpfi  3.62    3.39               8.0        182      5400       16
# 17         mpfi  3.62    3.39               8.0        182      5400       15
# 18         2bbl  2.91    3.03               9.5         48      5100       47
# 19         2bbl  3.03    3.11               9.6         70      5400       38
#
#    highway_mpg  price
# 0           27  13495
# 1           27  16500
# 2           26  16500
# 3           30  13950
# 4           22  17450
# 5           25  15250
# 6           25  17710
# 7           25  18920
# 8           20  23875
# 9           22      ?
# 10          29  16430
# 11          29  16925
# 12          28  20970
# 13          28  21105
# 14          25  24565
# 15          22  30760
# 16          22  41315
# 17          20  36880
# 18          53   5151
# 19          43   6295
#
# [20 rows x 26 columns]

# %%
cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized_losses  205 non-null    object
#  2   Fuel_type          205 non-null    object
#  3   make               205 non-null    object
#  4   num_of_doors       205 non-null    object
#  5   aspiration         205 non-null    object
#  6   wheel_base         205 non-null    object
#  7   engine_location    205 non-null    object
#  8   drive_wheels       205 non-null    float64
#  9   body_style         205 non-null    object
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb_weight        205 non-null    int64
#  14  engine_type        205 non-null    object
#  15  num_of_cylinders   205 non-null    object
#  16  engine_size        205 non-null    int64
#  17  fuel_system        205 non-null    object
#  18  bore               205 non-null    object
#  19  stroke             205 non-null    object
#  20  compression_ratio  205 non-null    float64
#  21  horsepower         205 non-null    object
#  22  peak_rpm           205 non-null    object
#  23  city_mpg           205 non-null    int64
#  24  highway_mpg        205 non-null    int64
#  25  price              205 non-null    object
# dtypes: float64(5), int64(5), object(16)
# memory usage: 41.8+ KB

# %%
cp.replace("?",np.nan, inplace=True)

# %%
cp.normalized_losses.value_counts()
# Out:
# normalized_losses
# 161    11
# 91      8
# 150     7
# 128     6
# 104     6
# 134     6
# 74      5
# 103     5
# 168     5
# 95      5
# 102     5
# 94      5
# 65      5
# 85      5
# 93      4
# 106     4
# 118     4
# 122     4
# 148     4
# 154     3
# 83      3
# 125     3
# 115     3
# 137     3
# 101     3
# 194     2
# 197     2
# 188     2
# 164     2
# 158     2
# 192     2
# 110     2
# 145     2
# 113     2
# 81      2
# 89      2
# 87      2
# 108     2
# 119     2
# 153     2
# 129     2
# 98      1
# 121     1
# 107     1
# 78      1
# 231     1
# 142     1
# 77      1
# 186     1
# 90      1
# 256     1
# Name: count, dtype: int64

# %%
cp.normalized_losses = pd.to_numeric(cp.normalized_losses)

# %%
cp.normalized_losses = cp.normalized_losses.fillna(cp.normalized_losses.mean())

# %%
cp.num_of_doors.value_counts()
# Out:
# num_of_doors
# four    114
# two      89
# Name: count, dtype: int64

# %%
cp.num_of_doors = cp.num_of_doors.fillna('four')

# %%
cp.bore.value_counts()
# Out:
# bore
# 3.62    23
# 3.19    20
# 3.15    15
# 2.97    12
# 3.03    12
# 3.46     9
# 3.31     8
# 3.43     8
# 3.78     8
# 2.91     7
# 3.27     7
# 3.54     6
# 3.58     6
# 3.39     6
# 3.05     6
# 3.7      5
# 3.01     5
# 3.35     4
# 3.74     3
# 3.17     3
# 3.59     3
# 3.13     2
# 3.24     2
# 3.5      2
# 3.47     2
# 3.94     2
# 3.8      2
# 3.63     2
# 3.33     2
# 2.68     1
# 3.76     1
# 3.08     1
# 3.6      1
# 2.92     1
# 3.34     1
# 2.99     1
# 2.54     1
# 3.61     1
# Name: count, dtype: int64

# %%
cp.bore = pd.to_numeric(cp.bore)

# %%
cp.bore = cp.bore.fillna(cp.bore.mean())

# %%
cp.stroke.value_counts()
# Out:
# stroke
# 3.4     20
# 3.15    14
# 3.23    14
# 3.03    14
# 3.39    13
# 2.64    11
# 3.29     9
# 3.35     9
# 3.46     8
# 3.58     6
# 3.41     6
# 3.07     6
# 3.27     6
# 3.11     6
# 3.19     6
# 3.5      6
# 3.52     5
# 3.64     5
# 3.47     4
# 3.86     4
# 3.54     4
# 2.9      3
# 3.9      3
# 2.68     2
# 2.8      2
# 3.08     2
# 4.17     2
# 3.1      2
# 2.19     2
# 2.76     1
# 3.16     1
# 3.12     1
# 3.21     1
# 2.07     1
# 2.36     1
# 2.87     1
# Name: count, dtype: int64

# %%
cp.stroke = pd.to_numeric(cp.stroke)

# %%
cp.stroke = cp.stroke.fillna(cp.stroke.mean())

# %%
cp.horsepower.value_counts()
# Out:
# horsepower
# 68     19
# 70     11
# 69     10
# 116     9
# 110     8
# 95      7
# 160     6
# 62      6
# 88      6
# 101     6
# 114     6
# 145     5
# 97      5
# 82      5
# 102     5
# 84      5
# 76      5
# 86      4
# 92      4
# 123     4
# 111     4
# 121     3
# 182     3
# 85      3
# 73      3
# 207     3
# 90      3
# 152     3
# 112     2
# 156     2
# 161     2
# 52      2
# 94      2
# 184     2
# 155     2
# 162     2
# 56      2
# 100     2
# 176     2
# 154     1
# 115     1
# 140     1
# 48      1
# 64      1
# 135     1
# 262     1
# 78      1
# 58      1
# 60      1
# 175     1
# 72      1
# 143     1
# 142     1
# 55      1
# 200     1
# 120     1
# 288     1
# 134     1
# 106     1
# Name: count, dtype: int64

# %%
cp.horsepower = pd.to_numeric(cp.horsepower)

# %%
cp.horsepower = cp.horsepower.fillna(cp.horsepower.mean())

# %%
cp.peak_rpm.value_counts()
# Out:
# peak_rpm
# 5500    37
# 4800    36
# 5000    27
# 5200    23
# 5400    13
# 6000     9
# 5800     7
# 4500     7
# 5250     7
# 4150     5
# 4200     5
# 4350     4
# 4750     4
# 5100     3
# 4250     3
# 4400     3
# 5900     3
# 6600     2
# 4650     1
# 5750     1
# 5600     1
# 4900     1
# 5300     1
# Name: count, dtype: int64

# %%
cp.peak_rpm = pd.to_numeric(cp.peak_rpm)

# %%
cp.peak_rpm = cp.peak_rpm.fillna(cp.peak_rpm.mean())

# %%
cp.price.value_counts()
# Out:
# price
# 16500    2
# 6229     2
# 7609     2
# 7957     2
# 6692     2
#         ..
# 16845    1
# 19045    1
# 21485    1
# 22470    1
# 22625    1
# Name: count, Length: 186, dtype: int64

# %%
cp.price = pd.to_numeric(cp.price)

# %%
cp.price = cp.price.fillna(cp.price.mean())

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
cp[cp.select_dtypes(include=['object']).columns] = cp[cp.select_dtypes(include=['object']).columns].apply(le.fit_transform)

# %%
from sklearn.model_selection import train_test_split

# %%
cp_train , cp_test = train_test_split(cp , test_size=0.2)

# %%
cp_train.shape
# Out:
# (164, 26)

# %%
cp_test.shape
# Out:
# (41, 26)

# %%
cp_train_x = cp_train.iloc[:, :-1]
cp_train_y = cp_train.iloc[:, -1]

# %%
cp_train_y
# Out:
# 105    19699.0
# 2      16500.0
# 48     35550.0
# 147    10198.0
# 117    18150.0
#         ...
# 136    18150.0
# 144     9233.0
# 180    15690.0
# 38      9095.0
# 145    11259.0
# Name: price, Length: 164, dtype: float64

# %%
cp_test_x = cp_train.iloc[:, :-1]
cp_test_y = cp_train.iloc[:, -1]

# %%
from sklearn.linear_model import LinearRegression

# %%
linereg = LinearRegression()

# %%
linereg.fit(cp_train_x , cp_train_y)
# Out:
# LinearRegression()

# %%
Rsquare = linereg.score(cp_train_x , cp_train_y)

# %%
Rsquare
# Out:
# 0.8899753226427338

# %%
N = cp_train_x.shape[0]
K = cp_train_x.shape[1]

# %%
Adj_Rsquare = 1-(1-Rsquare) * (N-1) / (N-K-1)
Adj_Rsquare
# Out:
# 0.8700433158751131

# %%
cp_train_x.columns
# Out:
# Index(['symboling', 'normalized_losses', 'Fuel_type', 'make', 'num_of_doors',
#        'aspiration', 'wheel_base', 'engine_location', 'drive_wheels',
#        'body_style', 'length', 'width', 'height', 'curb_weight', 'engine_type',
#        'num_of_cylinders', 'engine_size', 'fuel_system', 'bore', 'stroke',
#        'compression_ratio', 'horsepower', 'peak_rpm', 'city_mpg',
#        'highway_mpg'],
#       dtype='object')

# %%
linereg.coef_
# Out:
# array([ 4.33686190e+02, -1.24714946e+01,  9.34559610e+03,  4.16143876e+03,
#        -1.23944484e+03, -7.26364216e+02,  1.07220488e+03,  1.25432157e+04,
#         7.03977024e+01, -2.08487313e+02,  4.65822164e+00,  6.67864489e+02,
#         2.00476948e+02,  1.08732064e+00, -7.46048938e+01,  8.64266956e+02,
#         1.66595776e+02,  2.78340047e+02, -2.45630421e+03, -3.97057756e+03,
#         6.46523354e+02, -6.32413833e+01,  1.83283794e+00, -6.98226171e+01,
#         4.95939335e+01])

# %%
linereg.intercept_
# Out:
# np.float64(-68503.48765487986)

# %%
pred_train = linereg.predict(cp_train_x)
pred_test = linereg.predict(cp_test_x)

# %%
pred_test
# Out:
# array([21018.23460611, 17755.97603962, 32400.61044533,  9392.52470431,
#        18393.20071197,  8805.0655367 ,  7659.34043729,  6371.44669014,
#        11358.55711249, 19654.78330283, 13463.79026308,  8455.30712186,
#        15019.54772782,  9415.18429857,  6882.35360252, 15898.87423968,
#         9305.64924577,  8671.26382917, 10212.17905422,  9085.58257293,
#         9613.70338221,  8571.01202062, 21340.9961362 , 40728.94007887,
#        18558.56925468,  7058.20105562,  8933.5775345 ,  8267.49221012,
#         8451.83351073, 11415.65126153, 15504.9324753 ,  7938.20908683,
#        16030.51898519, 13580.33814356,  7483.42437312,  3761.48662215,
#        11072.16941546, 31556.26419805,  7175.99832934,  8705.31333873,
#        15420.69214369, 20607.15389046, 12870.12272415, 33278.        ,
#         9367.34219048,  8604.5153191 ,  7628.67593322,  8455.30712186,
#        17363.06476899,  5419.40494033,  6949.88862022, 26154.84970188,
#        11301.6568384 , 22722.99011062, 12714.63587286, 12777.4658404 ,
#        11714.20629399, 11714.20629399,  9881.74365417,  6863.45960423,
#        41677.76612656,  7538.81802405, 15009.22310628, 25456.5978478 ,
#        11072.16941546, 12456.88031976,  7968.82066702,  7508.55392433,
#        13650.26621752,  7920.81195661, 32113.76606895, 13035.87311057,
#        18028.64582783, 17997.27425608, 23210.86043605,  7656.1966313 ,
#        15684.48549894,  5829.86452527, 19327.89330056, 19484.61191889,
#        29711.09259055, 19166.0860652 ,  5708.90411039, 20047.88403337,
#         6968.77835615,  7205.83693958, 27021.19794864,  7268.28602185,
#        11678.20140515,  8841.45492217,  9520.13410177, 14637.97953346,
#         5568.87717454,  6943.67345436, 14567.34289324, 12539.47927556,
#         5124.1931403 , 15349.73658578,  6938.67485228, 25370.49338342,
#         6708.87328489, 25400.28796423, 17650.46841035,  9570.21055667,
#         9597.36304121, 12280.52309588, 15021.71389338, 20008.61243572,
#         9096.81524935,  6058.43781704, 19385.48013411, 16588.52557601,
#        20328.7377266 ,  5888.61357884, 13984.34327055, 15355.17318898,
#         7448.20114813,  7968.82066702,  7747.11304179,  9049.62450377,
#         7460.16505271, 19424.80928377,  6221.96104779, 10791.41171221,
#         5425.28197717,  9813.24245394,  7029.00029535,  6236.88100966,
#        10035.67350956, 15019.64944862,  7083.29536218,  7304.16760291,
#        14660.53876861, 12718.98515541, 16929.44343931,  5414.58034814,
#        12181.8147303 ,  5895.79617066, 33278.        ,  7965.64411708,
#         6616.35018254,  9359.56521628,  6992.96181731,  5900.7335052 ,
#        21781.33768568, 15069.02574139, 13383.1342034 ,  6694.5375785 ,
#        20152.18517536,  8875.93076196,  7863.26589494,  6173.45461401,
#        15481.81619569, 12967.37191035, 19484.61191889,  8518.51402169,
#        12407.80089379, 20373.13481132, 20166.39757518, 13965.05007933,
#         7746.73511838, 18730.35976016,  9790.44749275, 10681.34440305])

# %%
error_train = cp_train_y - pred_train
error_test = cp_test_y - pred_test

# %%
error_test
# Out:
# 105   -1319.234606
# 2     -1255.976040
# 48     3149.389555
# 147     805.475296
# 117    -243.200712
#           ...
# 136    4184.949921
# 144    1486.264882
# 180   -3040.359760
# 38     -695.447493
# 145     577.655597
# Name: price, Length: 164, dtype: float64

# %%
error_train
# Out:
# 105   -1319.234606
# 2     -1255.976040
# 48     3149.389555
# 147     805.475296
# 117    -243.200712
#           ...
# 136    4184.949921
# 144    1486.264882
# 180   -3040.359760
# 38     -695.447493
# 145     577.655597
# Name: price, Length: 164, dtype: float64

# %%
mse = np.mean(np.square(error_test))
mse
# Out:
# np.float64(6336499.176306143)

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# np.float64(2517.2403890582527)

# %%
mape = np.mean(np.abs(error_test * 100 / cp_test_y))
mape
# Out:
# np.float64(16.160548384579435)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(error_train, '*')

# %%
plt.hist(error_train , bins=30, edgecolor='r')
# Out:
# (array([ 2.,  2.,  1.,  0.,  1.,  1.,  0.,  2.,  8.,  7.,  8., 13., 13.,
#         15., 16., 11., 14.,  9.,  9.,  4.,  8.,  6.,  2.,  2.,  4.,  1.,
#          1.,  1.,  2.,  1.]),
#  array([-7108.15389046, -6632.25184713, -6156.3498038 , -5680.44776047,
#         -5204.54571714, -4728.64367381, -4252.74163048, -3776.83958715,
#         -3300.93754382, -2825.03550049, -2349.13345716, -1873.23141383,
#         -1397.32937049,  -921.42732716,  -445.52528383,    30.3767595 ,
#           506.27880283,   982.18084616,  1458.08288949,  1933.98493282,
#          2409.88697615,  2885.78901948,  3361.69106281,  3837.59310614,
#          4313.49514947,  4789.3971928 ,  5265.29923613,  5741.20127946,
#          6217.10332279,  6693.00536612,  7168.90740945]),
#  <BarContainer object of 30 artists>)

# %%
import seaborn as sns

# %%
pred_actual_df = pd.DataFrame()
pred_actual_df['Actual'] = cp_train_y
pred_actual_df['Predicted'] = pred_train
sns.jointplot(x='Actual', y='Predicted', data=pred_actual_df, kind='reg')

# %%
pred_actual_df
# Out:
#       Actual     Predicted
# 105  19699.0  21018.234606
# 2    16500.0  17755.976040
# 48   35550.0  32400.610445
# 147  10198.0   9392.524704
# 117  18150.0  18393.200712
# ..       ...           ...
# 136  18150.0  13965.050079
# 144   9233.0   7746.735118
# 180  15690.0  18730.359760
# 38    9095.0   9790.447493
# 145  11259.0  10681.344403
#
# [164 rows x 2 columns]

# %%
def remove_outliers(df, col, k):
    mean = df[col].mean()
    global df1
    sd = df[col].std()
    final_list = [x for x in df[col] if (x > mean - k * sd)]
    final_list = [x for x in df[col] if (x < mean + k * sd)]
    df1 = df.loc[df[col].isin(final_list)]; print(df_shape)
    print('Number of outliers removed ------>' , df.shape[0] - df1.shape[0])

# %%
df_shape = cp.shape

# %%
remove_outliers(cp,'price', 2)
# Out:
# (205, 26)
# Number of outliers removed ------> 14
